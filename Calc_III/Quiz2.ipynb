# %%
import sympy as smp
from sympy import *
import numpy as np
from numpy import *
import scipy as sp
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d
from scipy.integrate import odeint
from fractions import Fraction
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

x, y, t, n, a, b, C, c, r, u, s, A, i, j, k, z, w, q, m, h = smp.symbols('x y t n a b C c r u s A i j k z w q m h')
f, g, m = smp.symbols('f g m', cls=smp.Function)

# %% [markdown]
# # 1
#
# Find and sketch the domain for the function:
#
# f(x, y) = (sin(xy))/(x^2 + y^2 - 36)

# %%
x = np.linspace(-10, 10, 400)
y = np.linspace(-10, 10, 400)

X, Y = np.meshgrid(x, y)
Z = (np.sin(X*Y))/(X**2 + Y**2 - 36)

plt.figure(figsize=(6,6))
plt.contourf(X, Y, Z, levels=[-np.inf, 0], colors='blue', alpha=0.3)
plt.contour(X, Y, Z, levels=[0], colors='blue')
plt.xlim([-10, 10])
plt.ylim([-10, 10])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Domain of the inequality (x^2 - 25)(y^2 - 4) >= 0')
plt.grid(True)
plt.show()

# %% [markdown]
# # 2
#
# For the given function, complete parts (a) through (f) below:
#
# A: Find the function's domain
#
# B: Find the function's range
#
# C: Describe the function's level curves
#
# D: Find the boundary of the function's domain
#
# E: Determine if the domain is an open region, a closed region, or neither
#
# F: Decide if the domain is bounded or unbounded

# %%
# C

x = np.linspace(-5, 5, 400)
y = np.linspace(-5, 5, 400)

X, Y = np.meshgrid(x, y)
Z = 9*X**2 + 25*Y**2

plt.figure(figsize=(6,6))
CS = plt.contour(X, Y, Z, levels=[0, 1, 2, 3, 4], colors='blue')
plt.clabel(CS, inline=1, fontsize=10)
plt.xlim([-5, 5])
plt.ylim([-5, 5])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Level curves of the function')
plt.grid(True)
plt.show()

# %% [markdown]
# # 4

# %%
f = (4*x**2 - 12*x*y + 9*y**2)/(2*x - 3*y)

# Compute the limit as x -> 3
lim_x = smp.limit(f.subs(y, 2), x, 3)

# Compute the limit as y -> 2
lim_y = smp.limit(f.subs(x, 3), y, 2)

print('Limit as x -> 0:')
display(lim_x)
print('Limit as y -> 2:')
display(lim_y)
# Out:
# Limit as x -> 0:
# 0
# Limit as y -> 2:
# 0

# %%
f = (smp.sin(x**10 + y**10))/(x**10 + y**10)

# Compute the limit as x -> 0
lim_x = smp.limit(f.subs(y, 0), x, 0)

# Compute the limit as y -> 0
lim_y = smp.limit(f.subs(x, 0), y, 0)

print('Limit as x -> 0:')
display(lim_x)
print('Limit as y -> 0:')
display(lim_y)
# Out:
# Limit as x -> 0:
# 1
# Limit as y -> 0:
# 1

# %%
f = 6 / (9*x + 5*y)

# Compute the partial derivative of the function with respect to x
df_dx = smp.diff(f, x)

# Compute the partial derivative of the function with respect to y
df_dy = smp.diff(f, y)

print("Partial derivative with respect to x: ")
display(df_dx)
print("Partial derivative with respect to y: ")
display(df_dy)
# Out:
# Partial derivative with respect to x:
# -54/(9*x + 5*y)**2
# Partial derivative with respect to y:
# -30/(9*x + 5*y)**2

# %%
f = smp.ln(3*x + 7*y)

# Compute the partial derivative of the function with respect to x
df_dx = smp.diff(f, x)

# Compute the partial derivative of the function with respect to y
df_dy = smp.diff(f, y)

print("Partial derivative with respect to x: ")
display(df_dx)
print("Partial derivative with respect to y: ")
display(df_dy)
# Out:
# Partial derivative with respect to x:
# 3/(3*x + 7*y)
# Partial derivative with respect to y:
# 7/(3*x + 7*y)

# %%
from sympy import symbols, Function, diff

# Define the functions
g = Function('g')(m, n)
f = Function('f')(m, n)
k = Function('k')(m, n)
h = Function('h')(g, f, k)

# Compute partial derivatives
du_dm = diff(h, m)
du_dn = diff(h, n)

# Print the derivatives
print("Partial derivative of u with respect to m: ")
display(du_dm)
print("Partial derivative of u with respect to n: ")
display(du_dn)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph for dw/dq
G1 = nx.DiGraph()

# Add nodes
G1.add_node('q')
G1.add_node('x')
G1.add_node('y')
G1.add_node('w')

# Add edges
G1.add_edge('q', 'x', label='dx/dq')
G1.add_edge('q', 'y', label='dy/dq')
G1.add_edge('x', 'w', label='dw/dx')
G1.add_edge('y', 'w', label='dw/dy')

# Draw the graph
pos = nx.spring_layout(G1)
nx.draw(G1, pos, with_labels=True, node_color='lightblue', node_size=1500)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G1, 'label')
nx.draw_networkx_edge_labels(G1, pos, edge_labels=edge_labels)

plt.show()

# Create a directed graph for dw/dr
G2 = nx.DiGraph()

# Add nodes
G2.add_node('r')
G2.add_node('x')
G2.add_node('y')
G2.add_node('w')

# Add edges
G2.add_edge('r', 'x', label='dx/dr')
G2.add_edge('r', 'y', label='dy/dr')
G2.add_edge('x', 'w', label='dw/dx')
G2.add_edge('y', 'w', label='dw/dy')

# Draw the graph
pos = nx.spring_layout(G2)
nx.draw(G2, pos, with_labels=True, node_color='lightblue', node_size=1500)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G2, 'label')
nx.draw_networkx_edge_labels(G2, pos, edge_labels=edge_labels)

plt.show()

# %% [markdown]
# Find the gradient of the function f(x, y) = 6y - 10x at the point (8, 1)

# %%
# Define the function
f = 6*y - 10*x

# Compute the partial derivatives
f_x = smp.diff(f, x)
f_y = smp.diff(f, y)

# Substitute the point (-1, 3) into the partial derivatives
grad_x = f_x.subs({x: 8, y: 1})
grad_y = f_y.subs({x: 8, y: 1})

# Print the gradient
print((grad_x, grad_y))

# Answer:
# (-10)i + (6)j
# Out:
# (-10, 6)

# %%
# Define the function
def f(x, y):
    return 6*y - 10*x

# Create a grid of points
x = np.linspace(-50, 50, 100)
y = np.linspace(-50, 50, 100)
x, y = np.meshgrid(x, y)

# Compute the function values
z = f(x, y)

# Create a contour plot
plt.figure()
plt.contour(x, y, z, levels=np.linspace(0, 1, 100))

# Compute the gradient at the point (8, 1)
grad_x = -10
grad_y = 6

# Add an arrow representing the gradient
plt.quiver(8, 1, grad_x, grad_y, color='red', angles='xy', scale_units='xy', scale=1)

# Set labels
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %% [markdown]
# Find ▽f at the given point:
#
# f(x, y, z) = (smp.exp(x + y)) + smp.sin(z) + (y+8)*smp.cos(x)**-1
#
# (0, 0, pi/4)

# %%
from sympy import symbols, diff, log

# Define the variables
x, y, z = symbols('x y z')

# Define the function
f = (smp.exp(x + y)) + smp.sin(z) + (y+8)*smp.cos(x)**-1

# Compute the gradient
gradient = [diff(f, var) for var in (x, y, z)]

# Print the gradient
print("The gradient of f is:", gradient)

# Now, let's substitute the point (1, 4, 4) into the gradient
point = {x: 0, y: 0, z: smp.pi/4}
gradient_at_point = [derivative.evalf(subs=point) for derivative in gradient]

# Print the gradient at the point
print("The gradient of f at the point (0, 0, pi/4) is:")
gradient_at_point

# Answer:
# 1i + 2j + (sqrt(2)/2)k
# Out:
# The gradient of f is: [(y + 8)*sin(x)/cos(x)**2 + exp(x + y), exp(x + y) + 1/cos(x), cos(z)]
# The gradient of f at the point (0, 0, pi/4) is:
# [1.00000000000000, 2.00000000000000, 0.707106781186548]

# %% [markdown]
# Find the equation for the tangent plane and the normal line at the point
#
# (P_0)(8, 0, 8) on the surface 8z - x^2 = 0
#
# A: Using a coefficient of 2 for x, the equation for the tangent plane is: 2x - z - 8 = 0
#
# B: Find the equations for the normal line. Let x = 8 - 16t:
#
# x = 8 - 16t
#
# y = 0
#
# z = 8 + 8t

# %%
from sympy import symbols, diff, simplify

# Define the variables
x, y, z = symbols('x y z')

# Define the function
f = 3*x**2 + y**2 + 4*z**2 - 44

# Compute the gradient
fx = diff(f, x)
fy = diff(f, y)
fz = diff(f, z)

# Substitute the point (3, 1, 2) into the gradient
P_0 = {x: 3, y: 1, z: 2}
fx_0 = fx.subs(P_0)
fy_0 = fy.subs(P_0)
fz_0 = fz.subs(P_0)

# Define the equation of the tangent plane
tangent_plane = fx_0*(x - 3) + fy_0*(y - 1) + fz_0*(z - 2)

# Simplify the equation
tangent_plane = simplify(tangent_plane)

# Divide the equation by -3 to get a coefficient of 2 for x
tangent_plane = tangent_plane / 2

# Print the equation of the tangent plane
print("The equation of the tangent plane at the point (3, 1, 2) is: 0 =")
display(tangent_plane)
# Out:
# The equation of the tangent plane at the point (3, 1, 2) is: 0 =
# 9*x + y + 8*z - 44

# %%
from sympy import symbols, diff, solve

# Define the symbols
x, y = symbols('x y')

# Define the function
f = -9*x**2 - 9*x*y - 7*y**2 + 207*x + 170*y + 8

# First partial derivatives
f_x = diff(f, x)
f_y = diff(f, y)

# Critical points
critical_points = solve([f_x, f_y], (x, y))

# Second partial derivatives
f_xx = diff(f_x, x)
f_xy = diff(f_x, y)
f_yx = diff(f_y, x)
f_yy = diff(f_y, y)

# Since there's only one critical point, we don't need a loop
point = critical_points

# Evaluate second derivatives at the critical point
f_xx_val = f_xx.subs({x: point[x], y: point[y]})
f_xy_val = f_xy.subs({x: point[x], y: point[y]})
f_yx_val = f_yx.subs({x: point[x], y: point[y]})
f_yy_val = f_yy.subs({x: point[x], y: point[y]})

# Hessian determinant
D = f_xx_val*f_yy_val - f_xy_val*f_yx_val

# Classification of critical point
if D > 0 and f_xx_val > 0:
    print(f"Local minimum at {point}")
elif D > 0 and f_xx_val < 0:
    print(f"Local maximum at {point}")
elif D < 0:
    print(f"Saddle point at {point}")
# Out:
# Local maximum at {x: 8, y: 7}

# %%
from sympy import symbols, diff, solve

# Define the symbols
x, y = symbols('x y')

# Define the function
f = x**3 - 3*x*y + y**3

# First partial derivatives
f_x = diff(f, x)
f_y = diff(f, y)

# Critical points
critical_points = solve([f_x, f_y], (x, y))

# Second partial derivatives
f_xx = diff(f_x, x)
f_xy = diff(f_x, y)
f_yx = diff(f_y, x)
f_yy = diff(f_y, y)

# Since there's only one critical point, we don't need a loop
point = {x: critical_points[0][0], y: critical_points[0][1]}

# Evaluate second derivatives at the critical point
f_xx_val = f_xx.subs({x: point[x], y: point[y]})
f_xy_val = f_xy.subs({x: point[x], y: point[y]})
f_yx_val = f_yx.subs({x: point[x], y: point[y]})
f_yy_val = f_yy.subs({x: point[x], y: point[y]})

# Hessian determinant
D = f_xx_val*f_yy_val - f_xy_val*f_yx_val

# Classification of critical point
if D > 0 and f_xx_val > 0:
    print(f"Local minimum at {point}")
elif D > 0 and f_xx_val < 0:
    print(f"Local maximum at {point}")
elif D < 0:
    print(f"Saddle point at {point}")
# Out:
# Saddle point at {x: 0, y: 0}
